# %% [markdown]
# # Numpy

# %%
import numpy as np

# %% [markdown]
# # Most used in live environments

# %% [markdown]
# ## web scraping
# ## using API

# %% [markdown]
# what is an api?

# %%
import requests

# %%
token="EAAH8dFwSf8wBAIyWF7bVm1KT0CN3jitRTeVjXhRmUNhTf0hZBMuEfJGq8MXkAgI2uWHPE8h7eVoDXnIccq620t8ZBqyyfJKGuxRvAWXMMXGZAhvM8UShCZCFUzHZBkKP8kBJrZB4NSrPzFGorpE9VckFb0e4VH47ZBOgf70wZAMkpXotXNheIWYGzy9J0TaAgGMJAfiCwVAfRQZDZD"
query = input("enter")
url = f"https://graph.facebook.com/v3.3/me?fields={query}&access_token={token}"
page = requests.get(url)
print(page)
# Out:
# entername,birthday
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %%
page.text
# Out:
# '{"name":"Harshit Dwivedi","birthday":"07\\/25\\/1999","id":"457168178398412"}'

# %%
url = "https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500"
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
page.content[:10]
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF'

# %%
f = open("Myimage.jpeg","wb")
f.write(page.content)
f.close()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread("Myimage.jpeg")
print(img.shape)
plt.imshow(img)
plt.xticks([])
plt.yticks([])

plt.show()
# Out:
# (331, 500, 3)

# %%
def download(url,filename):
    #url = "https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500"
    page = requests.get(url)
    f = open(filename,"wb")
    f.write(page.content)
    f.close()
    img = plt.imread(filename)
    print(img.shape)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])

    plt.show()

# %%
download("https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500")
# Out:
# (331, 500, 3)

# %%
list1=["https://images.pexels.com/photos/414612/pexels-photo-414612.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500","https://images.pexels.com/photos/248797/pexels-photo-248797.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500"]
for i in range(2):
    download(list1[i],"abc"+str(i))
# Out:
# (355, 500, 3)
# (200, 500, 3)

# %%
page.headers['Content-Type']
# Out:
# 'image/jpeg'

# %%
page  = requests.get("https://grras.com")

# %%
page.status_code
# Out:
# 200

# %%
page.headers["Content-Type"]
# Out:
# 'text/html; charset=UTF-8'

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(page.text,'html')

# %%
links = soup.find_all("img")

# %%
len(links)
# Out:
# 59

# %%
e = links[0]

# %%
e.get('src')
# Out:
# 'https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=71x60'

# %%
urls = []
for link in links:
    urls.append(link.get('src'))

# %%
urls
# Out:
# ['https://grras.com/files/dakconwrechyzezn0f6b/logo_main.png?s=71x60',
#  'https://grras.com/files/v0n5yzrqfuprbxidndbx/Home page IT.jpg?s=1200x500',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/img/placeholder.png',
#  'https://grras.com/img/placeholder.png',
#  'img/aero.png',
#  'https://grras.com/img/placeholder.png',
#  'img/aero.png',
#  'https://grras.com/img/placeholder.png',
#  'img/aero.png',
#  'https://grras.com/img/placeholder.png',
#  'img/aero.png',
#  'https://grras.com/img/placeholder.png',
#  'img/aero.png',
#  'https://grras.com/img/placeholder.png',
#  'img/aero.png',
#  'https://grras.com/img/placeholder.png',
#  'img/aero.png',
#  'https://grras.com/files/i28m4farnlyzxx6wxpxs/redhat optimized.jpg?s=157x130',
#  'https://grras.com/files/6hmeh2rrc3gm57nngv49/CISCO optimized.jpg?s=157x130',
# ...

# %%
for url in urls:
    download(url,"abc"+url[:2])
# Out:
# (60, 71, 4)
# (500, 1200, 3)
# (21, 29, 4)
# (21, 29, 4)
# (21, 29, 4)
# (21, 29, 4)
# (21, 29, 4)
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-42-11877cc08781> in <module>
#       1 for url in urls:
# ----> 2     download(url,"abc"+url[:2])
#
# <ipython-input-14-d559c39bc3b9> in download(url, filename)
#       1 def download(url,filename):
#       2     #url = "https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500"
# ----> 3     page = requests.get(url)
#       4     f = open(filename,"wb")
#       5     f.write(page.content)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ...
